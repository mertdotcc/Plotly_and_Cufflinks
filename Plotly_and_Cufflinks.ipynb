# %% [markdown]
# # Plotly and Cufflinks for Creating Interactive Data Visualizations

# %% [markdown]
# - Plotly is an interactive visualization library
# - Cufflinks connects plotly with pandas
# - First we need to install them
#     - __pip install plotly__
#     and
#     - __pip install cufflinks__

# %%
import sys
print(sys.executable)
# Out:
# C:\DS\envs\myenv\python.exe

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import plotly

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 3.7.1

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
cf.go_offline()
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
df = pd.DataFrame(np.random.randn(100,4), columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  0.221571 -0.200811 -1.222031 -0.387357
# 1 -1.755491 -0.052407  0.134595  1.278454
# 2 -0.357246 -0.521599  0.092006 -1.379991
# 3  0.198013 -0.490555  0.452972 -0.103180
# 4 -1.561708  0.267645  1.363264 -0.477410

# %%
df2 = pd.DataFrame({'Category':['A','B','C'], 'Values':[32,43,50]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.plot()

# %% [markdown]
# Now, notice the difference!

# %%
df.iplot()
# Out:
# <div id="694c3129-9223-4576-bc29-b8971a73d665" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("694c3129-9223-4576-bc29-b8971a73d665")) {
# ...

# %%
df.iplot(kind='scatter', x='A', y='B')
# This happends because plotly tries to make lines out of data point.
# Out:
# <div id="5cf3c6f1-7cb7-4040-883d-456afd0be808" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("5cf3c6f1-7cb7-4040-883d-456afd0be808")) {
# ...

# %%
# To fix this:
df.iplot(kind='scatter', x='A', y='B', mode='markers')
# Out:
# <div id="c146138b-e704-42e8-a2ff-3153a6a979dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("c146138b-e704-42e8-a2ff-3153a6a979dc")) {
# ...

# %%
df.iplot(kind='scatter', x='A', y='B', mode='markers', size=20)
# Out:
# <div id="47e67fba-0ff7-4ac7-9230-c7e12da5706d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("47e67fba-0ff7-4ac7-9230-c7e12da5706d")) {
# ...

# %%
df2.iplot(kind='bar', x='Category', y='Values')
# Out:
# <div id="7ffe06f9-d513-4e42-8b03-da6e59ae54ee" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("7ffe06f9-d513-4e42-8b03-da6e59ae54ee")) {
# ...

# %%
df.sum().iplot(kind='bar')
# Out:
# <div id="f51c3889-5e01-4aeb-bea0-38cd6e916193" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("f51c3889-5e01-4aeb-bea0-38cd6e916193")) {
# ...

# %%
df.iplot(kind='box')
# Out:
# <div id="6b40b9b6-9297-4169-9cf2-c861019933dc" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("6b40b9b6-9297-4169-9cf2-c861019933dc")) {
# ...

# %% [markdown]
# ### 3D Surface Plots

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,10], 'z':[500,400,300,200,100]})
df3
# Out:
#    x   y    z
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100

# %%
df3.iplot(kind='surface')
# Out:
# <div id="b259bfd5-0c8c-47be-bb2f-890e71bd7802" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("b259bfd5-0c8c-47be-bb2f-890e71bd7802")) {
# ...

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5], 'y':[10,20,30,20,10], 'z':[5,4,3,2,1]})

# %%
df3.iplot(kind='surface')
# Out:
# <div id="ce098e4c-3078-4356-9bfc-80c4db449009" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("ce098e4c-3078-4356-9bfc-80c4db449009")) {
# ...

# %%
df3.iplot(kind='surface', colorscale='rdylbu')
# Out:
# <div id="b7ea63e4-1895-4bce-abbc-44135e79ab96" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("b7ea63e4-1895-4bce-abbc-44135e79ab96")) {
# ...

# %%
df['A'].iplot(kind='hist')
# Out:
# <div id="39d21d55-ee89-4ec1-9971-b1c71ac07cea" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("39d21d55-ee89-4ec1-9971-b1c71ac07cea")) {
# ...

# %%
df[['A','B']].iplot(kind='spread') # Widely used in finance
# Out:
# <div id="07d72022-739f-4994-97ed-0149117e1cbf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("07d72022-739f-4994-97ed-0149117e1cbf")) {
# ...

# %%
df.iplot(kind='bubble', x='A', y='B', size='C', colorscale='rdylbu')
# Out:
# <div id="527d9f89-6efe-4c9b-bf5b-56b24a27ab06" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("527d9f89-6efe-4c9b-bf5b-56b24a27ab06")) {
# ...

# %%
df.scatter_matrix()
# Out:
# <div id="89393b5d-4a27-49e0-95b2-8844d81f8c8d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";
# if (document.getElementById("89393b5d-4a27-49e0-95b2-8844d81f8c8d")) {
# ...

# %% [markdown]
# End.
